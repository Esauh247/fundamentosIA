# %%
### Laboratorio2
# 01/09/2029
# nombre del alumno
# problema realizar un sistema inteligente que indentifique si una plantannecesita riego para activar el sensor 
#*nivel de humedad  si el nivel es mayor al 40% la planta necesita riego
#si el nivel es iugal o myaor al 40% no nececita riego

# %%
print ("vamos a ayudar a tu plantita")
humedad = float(input("esribe el nivel de humedad"))
# Out:
# vamos a ayudar a tu plantita
# esribe el nivel de humedad 120

# %%
print ("datos almacenados")
print ("humedad= ", humedad )
# Out:
# datos almacenados
# humedad=  39.0

# %%
if humedad>=40 and humedad<=100: print("no necesita riego")
elif humedad>=1 and humedad<=39: print("necesita riego")
else: print ("escribe un valor del 0 al 100")
# Out:
# escribe un valor del 0 al 100
