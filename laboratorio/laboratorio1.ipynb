# %% [markdown]
# ## Labororatorio
# # 01/09/2026
# # alumno

# %%
print ("Mi primer sistema inteligente")
nombre = input("escriba si nombre aqui,  empezando por apellido paterno")
matricula = input("Escribe tu matricula")
promedio = float(input("escribe tu promedio"))
# Out:
# Mi primer sistema inteligente
# escriba si nombre aqui,  empezando por apellido paterno hernandez leon
# Escribe tu matricula alskjnfajnf
# escribe tu promedio 10

# %%
print ("datos almacenados")
print ("nombre= ", nombre)
print ("matricula= ", matricula)
print ("promedio= ", promedio)
# Out:
# datos almacenados
# nombre=  leon hernandez esau
# matricula=  12345678
# promedio=  1000000000000.0

# %%
if promedio>=8.0 and promedio <=10: print("exelente desempeño")
elif promedio<8.0 and promedio >=7: print ("ya vas por menos")
elif promedio<7.0 and promedio >= 6.0: print ("creo que no sirbes para esto")
else:
    print ("mejor vez a vender mota")
# Out:
# exelente desempeño
