# %%
###Laboratorio 4

# %%
servidorDispo = True
latencia = True
paquete = True 
trafico = True
servidorRespaldo = True
monitorea = True

# %%
condicionCritica = (servidorDispo==False and latencia==False and paquete== False and trafico==False and servidorRespaldo== False and monitorea==False)

# %%
print ("existe condicion critica?", condicionCritica)
# Out:
# existe condicion critica? False

# %%
print ("== supervicion de sistema ==")
print ("licensiado ingeniero doctor maestro rey mago hokague supuer sayayin Esau")

servidorDispo = input("El servidor esta disponible(s/n):").lower() == "n"
latencia = input ("La latencia supera el limite(s/n):").lower() == "s"
paquete = input("La perdida de paquetes supera el limite permitido(s/n):").lower() == "s"
trafico = input("El trafico de red es anormalmente alto(s/n):").lower() == "s"
servidorRespaldo = input("El servidor de respaldo esta disponible? (s/n):").lower() == "n"
monitorea = input("El sistema de monitoreo esta activo? (s/n):").lower() == "s"

condicionCritica = (servidorDispo==True and latencia==True and paquete== True and trafico==True and servidorRespaldo== True and monitorea==True) 

print ("Decision")
if condicionCritica == True :
    print("condiciones criticas")
else:
    print("todo esta bien")
# Out:
# == supervicion de sistema ==
# licensiado ingeniero doctor maestro rey mago hokague supuer sayayin Esau
# El servidor esta disponible(s/n): s
# La latencia supera el limite(s/n): n
# La perdida de paquetes supera el limite permitido(s/n): n
# El trafico de red es anormalmente alto(s/n): n
# El servidor de respaldo esta disponible? (s/n): s
# El sistema de monitoreo esta activo? (s/n): n
# Decision
# todo esta bien
